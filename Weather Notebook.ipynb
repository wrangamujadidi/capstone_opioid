# %%
import urllib.request
import json
import pandas as pd
import numpy as np
import csv

# %%
lat = 38.87296
long = -77.01065


#to put the lat, long inside the URL:

#url = "https://api.darksky.net/forecast/1fb8adfac09f5dacb0274c523ee6be7b/38.87296,-77.01065,\
#255589200?UNITS=us?exclude=currently,flags,hourly,minutely"

#to put the lat, long, month as variables:

# %%
with open('weather.csv', 'w', newline='') as f:
    
    writer = csv.writer(f)
    
    leading_zero = '0'

    for i in range(1,10):
    
        month = leading_zero + str(i) 
    
        for day in range (1, 29):
        
            if day < 10:
        
                day = leading_zero + str(day)
        
                url = "https://api.darksky.net/forecast/a8fba1fc52c32e40351b4ec75d723134/{},{},2016-{}-{}T12:00:00?UNITS=us?\
exclude=currently,flags,hourly,minutely".format(lat, long, month, day)

    
                def response(url):
                    with urllib.request.urlopen(url) as response:
                        return response.read()
        
                res = response(url)
                parsed = json.loads(res)
    
                temp = parsed['currently']['temperature']
                precip = parsed['currently']['precipIntensity']
                humidity = parsed['currently']['humidity']


                row = month, day, temp, precip, humidity
                writer.writerows([row])

                print ("day = ", day)
                print ("month = ", month)
            
            else: 
            
                url = "https://api.darksky.net/forecast/a8fba1fc52c32e40351b4ec75d723134/{},{},2016-{}-{}T12:00:00?UNITS=us?\
exclude=currently,flags,hourly,minutely".format(lat, long, month, day)

                def response(url):
                    with urllib.request.urlopen(url) as response:
                        return response.read()
        
        
                res = response(url)
                parsed = json.loads(res)
    
                temp = parsed['currently']['temperature']
                precip = parsed['currently']['precipIntensity']
                humidity = parsed['currently']['humidity']


                row = month, day, temp, precip, humidity
                writer.writerows([row])
        
                print ("day = ", day)
                print ("month = ", month)
        
        
    for month in range(10,13):
        
        for day in range (1, 29):
        
            if day < 10:
    
                day = leading_zero + str(day)
        
                url = "https://api.darksky.net/forecast/a8fba1fc52c32e40351b4ec75d723134/{},{},2016-{}-{}T12:00:00?UNITS=us?\
exclude=currently,flags,hourly,minutely".format(lat, long, month, day)

    
                def response(url):
                    with urllib.request.urlopen(url) as response:
                        return response.read()
        
        
                res = response(url)
                parsed = json.loads(res)
    
                temp = parsed['currently']['temperature']
                precip = parsed['currently']['precipIntensity']
                humidity = parsed['currently']['humidity']

                row = month, day, temp, precip, humidity
                writer.writerows([row])
 
            
            else: 
            
                url = "https://api.darksky.net/forecast/a8fba1fc52c32e40351b4ec75d723134/{},{},2016-{}-{}T12:00:00?UNITS=us?\
exclude=currently,flags,hourly,minutely".format(lat, long, month, day)

                def response(url):
                    with urllib.request.urlopen(url) as response:
                        return response.read()
        
        
                res = response(url)
                parsed = json.loads(res)
    
                temp = parsed['currently']['temperature']
                precip = parsed['currently']['precipIntensity']
                humidity = parsed['currently']['humidity']

                row = month, day, temp, precip, humidity
                writer.writerows([row])
# Out:
# day =  01
# month =  01
# day =  02
# month =  01
# day =  03
# month =  01
# day =  04
# month =  01
# day =  05
# month =  01
# day =  06
# month =  01
# day =  07
# month =  01
# day =  08
# month =  01
# day =  09
# month =  01
# day =  10
# month =  01
# day =  11
# month =  01
# day =  12
# month =  01
# day =  13
# month =  01
# day =  14
# month =  01
# day =  15
# month =  01
# day =  16
# month =  01
# day =  17
# month =  01
# day =  18
# month =  01
# day =  19
# month =  01
# day =  20
# month =  01
# day =  21
# month =  01
# day =  22
# month =  01
# day =  23
# month =  01
# day =  24
# month =  01
# day =  25
# month =  01
# day =  26
# month =  01
# day =  27
# month =  01
# day =  28
# month =  01
# day =  01
# month =  02
# day =  02
# month =  02
# day =  03
# month =  02
# day =  04
# month =  02
# day =  05
# month =  02
# day =  06
# month =  02
# day =  07
# month =  02
# day =  08
# month =  02
# day =  09
# month =  02
# day =  10
# month =  02
# day =  11
# month =  02
# day =  12
# month =  02
# day =  13
# month =  02
# day =  14
# month =  02
# day =  15
# month =  02
# day =  16
# month =  02
# day =  17
# month =  02
# day =  18
# month =  02
# day =  19
# month =  02
# day =  20
# month =  02
# day =  21
# month =  02
# day =  22
# month =  02
# day =  23
# month =  02
# day =  24
# month =  02
# day =  25
# month =  02
# day =  26
# month =  02
# day =  27
# month =  02
# day =  28
# month =  02
# day =  01
# month =  03
# day =  02
# month =  03
# day =  03
# month =  03
# day =  04
# month =  03
# day =  05
# month =  03
# day =  06
# month =  03
# day =  07
# month =  03
# day =  08
# month =  03
# day =  09
# month =  03
# day =  10
# month =  03
# day =  11
# month =  03
# day =  12
# month =  03
# day =  13
# month =  03
# day =  14
# month =  03
# day =  15
# month =  03
# day =  16
# month =  03
# day =  17
# month =  03
# day =  18
# month =  03
# day =  19
# month =  03
# day =  20
# month =  03
# day =  21
# month =  03
# day =  22
# month =  03
# day =  23
# month =  03
# day =  24
# month =  03
# day =  25
# month =  03
# day =  26
# month =  03
# day =  27
# month =  03
# day =  28
# month =  03
# day =  01
# month =  04
# day =  02
# month =  04
# day =  03
# month =  04
# day =  04
# month =  04
# day =  05
# month =  04
# day =  06
# month =  04
# day =  07
# month =  04
# day =  08
# month =  04
# day =  09
# month =  04
# day =  10
# month =  04
# day =  11
# month =  04
# day =  12
# month =  04
# day =  13
# month =  04
# day =  14
# month =  04
# day =  15
# month =  04
# day =  16
# month =  04
# day =  17
# month =  04
# day =  18
# month =  04
# day =  19
# month =  04
# day =  20
# month =  04
# day =  21
# month =  04
# day =  22
# month =  04
# day =  23
# month =  04
# day =  24
# month =  04
# day =  25
# month =  04
# day =  26
# month =  04
# day =  27
# month =  04
# day =  28
# month =  04
# day =  01
# month =  05
# day =  02
# month =  05
# day =  03
# month =  05
# day =  04
# month =  05
# day =  05
# month =  05
# day =  06
# month =  05
# day =  07
# month =  05
# day =  08
# month =  05
# day =  09
# month =  05
# day =  10
# month =  05
# day =  11
# month =  05
# day =  12
# month =  05
# day =  13
# month =  05
# day =  14
# month =  05
# day =  15
# month =  05
# day =  16
# month =  05
# day =  17
# month =  05
# day =  18
# month =  05
# day =  19
# month =  05
# day =  20
# month =  05
# day =  21
# month =  05
# day =  22
# month =  05
# day =  23
# month =  05
# day =  24
# month =  05
# day =  25
# month =  05
# day =  26
# month =  05
# day =  27
# month =  05
# day =  28
# month =  05
# day =  01
# month =  06
# day =  02
# month =  06
# day =  03
# month =  06
# day =  04
# month =  06
# day =  05
# month =  06
# day =  06
# month =  06
# day =  07
# month =  06
# day =  08
# month =  06
# day =  09
# month =  06
# day =  10
# month =  06
# day =  11
# month =  06
# day =  12
# month =  06
# day =  13
# month =  06
# day =  14
# month =  06
# day =  15
# month =  06
# day =  16
# month =  06
# day =  17
# month =  06
# day =  18
# month =  06
# day =  19
# month =  06
# day =  20
# month =  06
# day =  21
# month =  06
# day =  22
# month =  06
# day =  23
# month =  06
# day =  24
# month =  06
# day =  25
# month =  06
# day =  26
# month =  06
# day =  27
# month =  06
# day =  28
# month =  06
# day =  01
# month =  07
# day =  02
# month =  07
# day =  03
# month =  07
# day =  04
# month =  07
# day =  05
# month =  07
# day =  06
# month =  07
# day =  07
# month =  07
# day =  08
# month =  07
# day =  09
# month =  07
# day =  10
# month =  07
# day =  11
# month =  07
# day =  12
# month =  07
# day =  13
# month =  07
# day =  14
# month =  07
# day =  15
# month =  07
# day =  16
# month =  07
# day =  17
# month =  07
# day =  18
# month =  07
# day =  19
# month =  07
# day =  20
# month =  07
# day =  21
# month =  07
# day =  22
# month =  07
# day =  23
# month =  07
# day =  24
# month =  07
# day =  25
# month =  07
# day =  26
# month =  07
# day =  27
# month =  07
# day =  28
# month =  07
# day =  01
# month =  08
# day =  02
# month =  08
# day =  03
# month =  08
# day =  04
# month =  08
# day =  05
# month =  08
# day =  06
# month =  08
# day =  07
# month =  08
# day =  08
# month =  08
# day =  09
# month =  08
# day =  10
# month =  08
# day =  11
# month =  08
# day =  12
# month =  08
# day =  13
# month =  08
# day =  14
# month =  08
# day =  15
# month =  08
# day =  16
# month =  08
# day =  17
# month =  08
# day =  18
# month =  08
# day =  19
# month =  08
# day =  20
# month =  08
# day =  21
# month =  08
# day =  22
# month =  08
# day =  23
# month =  08
# day =  24
# month =  08
# day =  25
# month =  08
# day =  26
# month =  08
# day =  27
# month =  08
# day =  28
# month =  08
# day =  01
# month =  09
# day =  02
# month =  09
# day =  03
# month =  09
# day =  04
# month =  09
# day =  05
# month =  09
# day =  06
# month =  09
# day =  07
# month =  09
# day =  08
# month =  09
# day =  09
# month =  09
# day =  10
# month =  09
# day =  11
# month =  09
# day =  12
# month =  09
# day =  13
# month =  09
# day =  14
# month =  09
# day =  15
# month =  09
# day =  16
# month =  09
# day =  17
# month =  09
# day =  18
# month =  09
# day =  19
# month =  09
# day =  20
# month =  09
# day =  21
# month =  09
# day =  22
# month =  09
# day =  23
# month =  09
# day =  24
# month =  09
# day =  25
# month =  09
# day =  26
# month =  09
# day =  27
# month =  09
# day =  28
# month =  09
# day =  01
# month =  10
# day =  02
# month =  10
# day =  03
# month =  10
# day =  04
# month =  10
# day =  05
# month =  10
# day =  06
# month =  10
# day =  07
# month =  10
# day =  08
# month =  10
# day =  09
# month =  10
# day =  10
# month =  10
# day =  11
# month =  10
# day =  12
# month =  10
# day =  13
# month =  10
# day =  14
# month =  10
# day =  15
# month =  10
# day =  16
# month =  10
# day =  17
# month =  10
# day =  18
# month =  10
# day =  19
# month =  10
# day =  20
# month =  10
# day =  21
# month =  10
# day =  22
# month =  10
# day =  23
# month =  10
# day =  24
# month =  10
# day =  25
# month =  10
# day =  26
# month =  10
# day =  27
# month =  10
# day =  28
# month =  10
# day =  01
# month =  11
# day =  02
# month =  11
# day =  03
# month =  11
# day =  04
# month =  11
# day =  05
# month =  11
# day =  06
# month =  11
# day =  07
# month =  11
# day =  08
# month =  11
# day =  09
# month =  11
# day =  10
# month =  11
# day =  11
# month =  11
# day =  12
# month =  11
# day =  13
# month =  11
# day =  14
# month =  11
# day =  15
# month =  11
# day =  16
# month =  11
# day =  17
# month =  11
# day =  18
# month =  11
# day =  19
# month =  11
# day =  20
# month =  11
# day =  21
# month =  11
# day =  22
# month =  11
# day =  23
# month =  11
# day =  24
# month =  11
# day =  25
# month =  11
# day =  26
# month =  11
# day =  27
# month =  11
# day =  28
# month =  11
# day =  01
# month =  12
# day =  02
# month =  12
# day =  03
# month =  12
# day =  04
# month =  12
# day =  05
# month =  12
# day =  06
# month =  12
# day =  07
# month =  12
# day =  08
# month =  12
# day =  09
# month =  12
# day =  10
# month =  12
# day =  11
# month =  12
# day =  12
# month =  12
# day =  13
# month =  12
# day =  14
# month =  12
# day =  15
# month =  12
# day =  16
# month =  12
# day =  17
# month =  12
# day =  18
# month =  12
# day =  19
# month =  12
# day =  20
# month =  12
# day =  21
# month =  12
# day =  22
# month =  12
# day =  23
# month =  12
# day =  24
# month =  12
# day =  25
# month =  12
# day =  26
# month =  12
# day =  27
# month =  12
# day =  28
# month =  12

# %%
parsed
# Out:
# {'currently': {'apparentTemperature': 41.7,
#   'cloudCover': 0.19,
#   'dewPoint': 25.87,
#   'humidity': 0.46,
#   'icon': 'clear-day',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'pressure': 1021.99,
#   'summary': 'Clear',
#   'temperature': 45.63,
#   'time': 1482944400,
#   'uvIndex': 2,
#   'visibility': 10,
#   'windBearing': 315,
#   'windSpeed': 7.45},
#  'daily': {'data': [{'apparentTemperatureMax': 50.54,
#     'apparentTemperatureMaxTime': 1482901200,
#     'apparentTemperatureMin': 36.47,
#     'apparentTemperatureMinTime': 1482930000,
#     'cloudCover': 0.07,
#     'dewPoint': 28.78,
#     'humidity': 0.54,
#     'icon': 'clear-day',
#     'moonPhase': 0.98,
#     'precipIntensity': 0,
#     'precipIntensityMax': 0,
#     'precipProbability': 0,
#     'pressure': 1019.86,
#     'summary': 'Clear throughout the day.',
#     'sunriseTime': 1482928028,
#     'sunsetTime': 1482962096,
#     'temperatureMax': 50.54,
#     'temperatureMaxTime': 1482901200,
#     'temperatureMin': 39.16,
#     'temperatureMinTime': 1482984000,
#     'time': 1482901200,
#     'uvIndex': 2,
#     'uvIndexTime': 1482944400,
#     'visibility': 10,
#     'windBearing': 319,
#     'windSpeed': 4.93}]},
#  'flags': {'isd-stations': ['720334-93764',
#    '722158-99999',
#    '722244-00358',
#    '724030-93738',
#    '724035-13773',
#    '724036-03710',
#    '724037-93728',
#    '724050-13743',
#    '724055-03714',
#    '724060-93721',
#    '724065-99999',
#    '745940-13705',
#    '994400-99999',
#    '997314-99999',
#    '998409-99999',
#    '999999-13752'],
#   'sources': ['isd'],
#   'units': 'us'},
#  'hourly': {'data': [{'apparentTemperature': 50.54,
#     'cloudCover': 0,
#     'dewPoint': 31.84,
#     'humidity': 0.48,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1015.49,
#     'summary': 'Clear',
#     'temperature': 50.54,
#     'time': 1482901200,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 320,
#     'windSpeed': 8.82},
#    {'apparentTemperature': 44.62,
#     'cloudCover': 0,
#     'dewPoint': 31.11,
#     'humidity': 0.49,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1015.82,
#     'summary': 'Clear',
#     'temperature': 49.37,
#     'time': 1482904800,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 324,
#     'windSpeed': 12.01},
#    {'apparentTemperature': 42.59,
#     'cloudCover': 0,
#     'dewPoint': 29.92,
#     'humidity': 0.5,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1016.43,
#     'summary': 'Clear',
#     'temperature': 47.58,
#     'time': 1482908400,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 322,
#     'windSpeed': 11.34},
#    {'apparentTemperature': 41.06,
#     'cloudCover': 0,
#     'dewPoint': 30.12,
#     'humidity': 0.53,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1017.16,
#     'summary': 'Clear',
#     'temperature': 46.35,
#     'time': 1482912000,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 329,
#     'windSpeed': 11.29},
#    {'apparentTemperature': 40.21,
#     'cloudCover': 0.01,
#     'dewPoint': 28.86,
#     'humidity': 0.52,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1017.95,
#     'summary': 'Clear',
#     'temperature': 45.23,
#     'time': 1482915600,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 321,
#     'windSpeed': 9.78},
#    {'apparentTemperature': 39,
#     'cloudCover': 0,
#     'dewPoint': 28.02,
#     'humidity': 0.53,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1018.85,
#     'summary': 'Clear',
#     'temperature': 44.03,
#     'time': 1482919200,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 308,
#     'windSpeed': 9.09},
#    {'apparentTemperature': 40.86,
#     'cloudCover': 0,
#     'dewPoint': 27.62,
#     'humidity': 0.54,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1019.74,
#     'summary': 'Clear',
#     'temperature': 42.93,
#     'time': 1482922800,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 323,
#     'windSpeed': 3.82},
#    {'apparentTemperature': 37.75,
#     'cloudCover': 0.01,
#     'dewPoint': 27.97,
#     'humidity': 0.6,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1020.7,
#     'summary': 'Clear',
#     'temperature': 40.82,
#     'time': 1482926400,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 335,
#     'windSpeed': 4.6},
#    {'apparentTemperature': 36.47,
#     'cloudCover': 0.15,
#     'dewPoint': 28.32,
#     'humidity': 0.61,
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1021.54,
#     'summary': 'Clear',
#     'temperature': 40.85,
#     'time': 1482930000,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 309,
#     'windSpeed': 6.47},
#    {'apparentTemperature': 37.05,
#     'cloudCover': 0.19,
#     'dewPoint': 26.31,
#     'humidity': 0.53,
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1022.35,
#     'summary': 'Clear',
#     'temperature': 42.29,
#     'time': 1482933600,
#     'uvIndex': 1,
#     'visibility': 10,
#     'windBearing': 315,
#     'windSpeed': 8.67},
#    {'apparentTemperature': 37.44,
#     'cloudCover': 0.18,
#     'dewPoint': 26.08,
#     'humidity': 0.5,
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1023,
#     'summary': 'Clear',
#     'temperature': 43.45,
#     'time': 1482937200,
#     'uvIndex': 1,
#     'visibility': 10,
#     'windBearing': 310,
#     'windSpeed': 11.28},
#    {'apparentTemperature': 41.04,
#     'cloudCover': 0.18,
#     'dewPoint': 26.11,
#     'humidity': 0.48,
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1022.72,
#     'summary': 'Clear',
#     'temperature': 44.68,
#     'time': 1482940800,
#     'uvIndex': 1,
#     'visibility': 10,
#     'windBearing': 322,
#     'windSpeed': 6.53},
#    {'apparentTemperature': 41.7,
#     'cloudCover': 0.19,
#     'dewPoint': 25.87,
#     'humidity': 0.46,
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1021.99,
#     'summary': 'Clear',
#     'temperature': 45.63,
#     'time': 1482944400,
#     'uvIndex': 2,
#     'visibility': 10,
#     'windBearing': 315,
#     'windSpeed': 7.45},
#    {'apparentTemperature': 42.99,
#     'cloudCover': 0.18,
#     'dewPoint': 25.75,
#     'humidity': 0.44,
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1021.06,
#     'summary': 'Clear',
#     'temperature': 46.71,
#     'time': 1482948000,
#     'uvIndex': 2,
#     'visibility': 10,
#     'windBearing': 316,
#     'windSpeed': 7.49},
#    {'apparentTemperature': 44.91,
#     'cloudCover': 0.17,
#     'dewPoint': 25.35,
#     'humidity': 0.41,
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1020.73,
#     'summary': 'Clear',
#     'temperature': 47.73,
#     'time': 1482951600,
#     'uvIndex': 1,
#     'visibility': 10,
#     'windBearing': 299,
#     'windSpeed': 6.1},
#    {'apparentTemperature': 46.87,
#     'cloudCover': 0.16,
#     'dewPoint': 25.21,
#     'humidity': 0.39,
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1020.49,
#     'summary': 'Clear',
#     'temperature': 49,
#     'time': 1482955200,
#     'uvIndex': 1,
#     'visibility': 10,
#     'windBearing': 290,
#     'windSpeed': 5.29},
#    {'apparentTemperature': 47.73,
#     'cloudCover': 0.15,
#     'dewPoint': 26,
#     'humidity': 0.4,
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1020.32,
#     'summary': 'Clear',
#     'temperature': 49.41,
#     'time': 1482958800,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 329,
#     'windSpeed': 4.68},
#    {'apparentTemperature': 46.32,
#     'cloudCover': 0.16,
#     'dewPoint': 30.58,
#     'humidity': 0.54,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1019.85,
#     'summary': 'Clear',
#     'temperature': 46.32,
#     'time': 1482962400,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 27,
#     'windSpeed': 2.93},
#    {'apparentTemperature': 44.71,
#     'cloudCover': 0.01,
#     'dewPoint': 32.22,
#     'humidity': 0.61,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1020.08,
#     'summary': 'Clear',
#     'temperature': 44.71,
#     'time': 1482966000,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 100,
#     'windSpeed': 1.92},
#    {'apparentTemperature': 42.98,
#     'cloudCover': 0.01,
#     'dewPoint': 30.81,
#     'humidity': 0.62,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1020.37,
#     'summary': 'Clear',
#     'temperature': 42.98,
#     'time': 1482969600,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 106,
#     'windSpeed': 2.32},
#    {'apparentTemperature': 41.54,
#     'cloudCover': 0.01,
#     'dewPoint': 31.75,
#     'humidity': 0.68,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1020.49,
#     'summary': 'Clear',
#     'temperature': 41.54,
#     'time': 1482973200,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 121,
#     'windSpeed': 2.26},
#    {'apparentTemperature': 39.93,
#     'cloudCover': 0,
#     'dewPoint': 31.48,
#     'humidity': 0.72,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1020.34,
#     'summary': 'Clear',
#     'temperature': 39.93,
#     'time': 1482976800,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 131,
#     'windSpeed': 2.8},
#    {'apparentTemperature': 36.64,
#     'cloudCover': 0,
#     'dewPoint': 31.48,
#     'humidity': 0.73,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1019.9,
#     'summary': 'Clear',
#     'temperature': 39.25,
#     'time': 1482980400,
#     'uvIndex': 0,
#     'visibility': 9.95,
#     'windBearing': 158,
#     'windSpeed': 3.8},
#    {'apparentTemperature': 36.85,
#     'cloudCover': 0,
#     'dewPoint': 32.01,
#     'humidity': 0.75,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1019.16,
#     'summary': 'Clear',
#     'temperature': 39.16,
#     'time': 1482984000,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 148,
#     'windSpeed': 3.5}],
#   'icon': 'clear-day',
#   'summary': 'Clear throughout the day.'},
#  'latitude': 38.87296,
#  'longitude': -77.01065,
#  'offset': -5,
#  'timezone': 'America/New_York'}

# %%
df = pd.read_csv('weather.csv')
df
# Out:
#      01  01.1  44.51       0  0.57
# 0     1     2  44.69  0.0000  0.43
# 1     1     3  47.56  0.0000  0.46
# 2     1     4  36.14  0.0000  0.40
# 3     1     5  27.50  0.0000  0.35
# 4     1     6  34.66  0.0000  0.33
# 5     1     7  39.70  0.0000  0.82
# 6     1     8  41.77  0.0000  0.95
# 7     1     9  46.12  0.0000  0.93
# 8     1    10  60.13  0.0000  0.67
# 9     1    11  36.13  0.0000  0.31
# 10    1    12  41.16  0.0000  0.39
# 11    1    13  26.72  0.0000  0.33
# 12    1    14  42.81  0.0000  0.41
# 13    1    15  47.37  0.0000  0.55
# 14    1    16  45.42  0.0000  0.84
# 15    1    17  33.77  0.0000  0.87
# 16    1    18  22.53  0.0000  0.39
# 17    1    19  22.03  0.0000  0.37
# 18    1    20  27.35  0.0000  0.42
# 19    1    21  30.33  0.0000  0.55
# 20    1    22  28.81  0.0000  0.54
# 21    1    23  27.24  0.0043  0.85
# 22    1    24  30.16  0.0000  0.45
# 23    1    25  35.38  0.0000  0.51
# 24    1    26  45.58  0.0016  0.51
# 25    1    27  41.16  0.0000  0.49
# 26    1    28  37.30  0.0000  0.56
# 27    2     1  56.57  0.0000  0.62
# 28    2     2  47.69  0.0000  0.54
# 29    2     3  48.98  0.0030  0.92
# ..   ..   ...    ...     ...   ...
# 305  11    27  49.23  0.0000  0.42
# 306  11    28  47.68  0.0000  0.55
# 307  12     1  55.18  0.0000  0.43
# 308  12     2  49.54  0.0000  0.42
# 309  12     3  48.26  0.0000  0.46
# 310  12     4  45.01  0.0000  0.54
# 311  12     5  51.84  0.0000  0.67
# 312  12     6  41.86  0.0339  0.84
# 313  12     7  47.67  0.0000  0.60
# 314  12     8  46.00  0.0000  0.39
# 315  12     9  37.33  0.0000  0.42
# 316  12    10  35.28  0.0000  0.39
# 317  12    11  35.91  0.0000  0.51
# 318  12    12  47.31  0.0000  0.91
# 319  12    13  43.21  0.0000  0.60
# 320  12    14  44.60  0.0000  0.45
# 321  12    15  24.51  0.0000  0.24
# 322  12    16  24.20  0.0000  0.31
# 323  12    17  33.07  0.0041  0.94
# 324  12    18  57.17  0.0000  0.86
# 325  12    19  34.94  0.0000  0.48
# 326  12    20  33.01  0.0000  0.47
# 327  12    21  44.88  0.0000  0.40
# 328  12    22  51.24  0.0000  0.38
# 329  12    23  43.70  0.0000  0.47
# 330  12    24  44.22  0.0054  0.95
# 331  12    25  46.86  0.0000  0.67
# 332  12    26  43.65  0.0000  0.78
# 333  12    27  60.00  0.0000  0.75
# 334  12    28  45.63  0.0000  0.46
#
# [335 rows x 5 columns]

# %%
df.columns = ["month", "day", "temp", "precip", "humidity"]

# %%
df
# Out:
#      month  day   temp  precip  humidity
# 0        1    2  44.69  0.0000      0.43
# 1        1    3  47.56  0.0000      0.46
# 2        1    4  36.14  0.0000      0.40
# 3        1    5  27.50  0.0000      0.35
# 4        1    6  34.66  0.0000      0.33
# 5        1    7  39.70  0.0000      0.82
# 6        1    8  41.77  0.0000      0.95
# 7        1    9  46.12  0.0000      0.93
# 8        1   10  60.13  0.0000      0.67
# 9        1   11  36.13  0.0000      0.31
# 10       1   12  41.16  0.0000      0.39
# 11       1   13  26.72  0.0000      0.33
# 12       1   14  42.81  0.0000      0.41
# 13       1   15  47.37  0.0000      0.55
# 14       1   16  45.42  0.0000      0.84
# 15       1   17  33.77  0.0000      0.87
# 16       1   18  22.53  0.0000      0.39
# 17       1   19  22.03  0.0000      0.37
# 18       1   20  27.35  0.0000      0.42
# 19       1   21  30.33  0.0000      0.55
# 20       1   22  28.81  0.0000      0.54
# 21       1   23  27.24  0.0043      0.85
# 22       1   24  30.16  0.0000      0.45
# 23       1   25  35.38  0.0000      0.51
# 24       1   26  45.58  0.0016      0.51
# 25       1   27  41.16  0.0000      0.49
# 26       1   28  37.30  0.0000      0.56
# 27       2    1  56.57  0.0000      0.62
# 28       2    2  47.69  0.0000      0.54
# 29       2    3  48.98  0.0030      0.92
# ..     ...  ...    ...     ...       ...
# 305     11   27  49.23  0.0000      0.42
# 306     11   28  47.68  0.0000      0.55
# 307     12    1  55.18  0.0000      0.43
# 308     12    2  49.54  0.0000      0.42
# 309     12    3  48.26  0.0000      0.46
# 310     12    4  45.01  0.0000      0.54
# 311     12    5  51.84  0.0000      0.67
# 312     12    6  41.86  0.0339      0.84
# 313     12    7  47.67  0.0000      0.60
# 314     12    8  46.00  0.0000      0.39
# 315     12    9  37.33  0.0000      0.42
# 316     12   10  35.28  0.0000      0.39
# 317     12   11  35.91  0.0000      0.51
# 318     12   12  47.31  0.0000      0.91
# 319     12   13  43.21  0.0000      0.60
# 320     12   14  44.60  0.0000      0.45
# 321     12   15  24.51  0.0000      0.24
# 322     12   16  24.20  0.0000      0.31
# 323     12   17  33.07  0.0041      0.94
# 324     12   18  57.17  0.0000      0.86
# 325     12   19  34.94  0.0000      0.48
# 326     12   20  33.01  0.0000      0.47
# 327     12   21  44.88  0.0000      0.40
# 328     12   22  51.24  0.0000      0.38
# 329     12   23  43.70  0.0000      0.47
# 330     12   24  44.22  0.0054      0.95
# 331     12   25  46.86  0.0000      0.67
# 332     12   26  43.65  0.0000      0.78
# 333     12   27  60.00  0.0000      0.75
# 334     12   28  45.63  0.0000      0.46
#
# [335 rows x 5 columns]
