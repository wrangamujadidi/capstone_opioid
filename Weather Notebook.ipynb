# %%
import urllib.request
import json
import pandas as pd
import numpy as np
import csv

# %%
lat = 38.889939
long = -77.009051


#to put the lat, long inside the URL:

#url = "https://api.darksky.net/forecast/1fb8adfac09f5dacb0274c523ee6be7b/38.87296,-77.01065,\
#255589200?UNITS=us?exclude=currently,flags,hourly,minutely"

#to put the lat, long, month as variables:

# %%
with open('weather.csv', 'w', newline='') as f:
    
    writer = csv.writer(f)
    
    leading_zero = '0'

    for i in range(1,10):
    
        month = leading_zero + str(i) 
    
        for day in range (1, 29):
        
            if day < 10:
        
                day = leading_zero + str(day)
        
                url = "https://api.darksky.net/forecast/a8fba1fc52c32e40351b4ec75d723134/{},{},2016-{}-{}T12:00:00?UNITS=us?\
exclude=currently,flags,hourly,minutely".format(lat, long, month, day)

    
                def response(url):
                    with urllib.request.urlopen(url) as response:
                        return response.read()
        
                res = response(url)
                parsed = json.loads(res)
    
                temp = parsed['currently']['temperature']
                precip = parsed['currently']['precipIntensity']
                humidity = parsed['currently']['humidity']


                row = month, day, temp, precip, humidity
                writer.writerows([row])

                print ("day = ", day)
                print ("month = ", month)
            
            else: 
            
                url = "https://api.darksky.net/forecast/a8fba1fc52c32e40351b4ec75d723134/{},{},2016-{}-{}T12:00:00?UNITS=us?\
exclude=currently,flags,hourly,minutely".format(lat, long, month, day)

                def response(url):
                    with urllib.request.urlopen(url) as response:
                        return response.read()
        
        
                res = response(url)
                parsed = json.loads(res)
    
                temp = parsed['currently']['temperature']
                precip = parsed['currently']['precipIntensity']
                humidity = parsed['currently']['humidity']


                row = month, day, temp, precip, humidity
                writer.writerows([row])
        
                print ("day = ", day)
                print ("month = ", month)
        
        
    for month in range(10,13):
        
        for day in range (1, 29):
        
            if day < 10:
    
                day = leading_zero + str(day)
        
                url = "https://api.darksky.net/forecast/a8fba1fc52c32e40351b4ec75d723134/{},{},2016-{}-{}T12:00:00?UNITS=us?\
exclude=currently,flags,hourly,minutely".format(lat, long, month, day)

    
                def response(url):
                    with urllib.request.urlopen(url) as response:
                        return response.read()
        
        
                res = response(url)
                parsed = json.loads(res)
    
                temp = parsed['currently']['temperature']
                precip = parsed['currently']['precipIntensity']
                humidity = parsed['currently']['humidity']

                row = month, day, temp, precip, humidity
                writer.writerows([row])
 
            
            else: 
            
                url = "https://api.darksky.net/forecast/a8fba1fc52c32e40351b4ec75d723134/{},{},2016-{}-{}T12:00:00?UNITS=us?\
exclude=currently,flags,hourly,minutely".format(lat, long, month, day)

                def response(url):
                    with urllib.request.urlopen(url) as response:
                        return response.read()
        
        
                res = response(url)
                parsed = json.loads(res)
    
                temp = parsed['currently']['temperature']
                precip = parsed['currently']['precipIntensity']
                humidity = parsed['currently']['humidity']

                row = month, day, temp, precip, humidity
                writer.writerows([row])
# Out:
# day =  01
# month =  01
# day =  02
# month =  01
# day =  03
# month =  01
# day =  04
# month =  01
# day =  05
# month =  01
# day =  06
# month =  01
# day =  07
# month =  01
# day =  08
# month =  01
# day =  09
# month =  01
# day =  10
# month =  01
# day =  11
# month =  01
# day =  12
# month =  01
# day =  13
# month =  01
# day =  14
# month =  01
# day =  15
# month =  01
# day =  16
# month =  01
# day =  17
# month =  01
# day =  18
# month =  01
# day =  19
# month =  01
# day =  20
# month =  01
# day =  21
# month =  01
# day =  22
# month =  01
# day =  23
# month =  01
# day =  24
# month =  01
# day =  25
# month =  01
# day =  26
# month =  01
# day =  27
# month =  01
# day =  28
# month =  01
# day =  01
# month =  02
# day =  02
# month =  02
# day =  03
# month =  02
# day =  04
# month =  02
# day =  05
# month =  02
# day =  06
# month =  02
# day =  07
# month =  02
# day =  08
# month =  02
# day =  09
# month =  02
# day =  10
# month =  02
# day =  11
# month =  02
# day =  12
# month =  02
# day =  13
# month =  02
# day =  14
# month =  02
# day =  15
# month =  02
# day =  16
# month =  02
# day =  17
# month =  02
# day =  18
# month =  02
# day =  19
# month =  02
# day =  20
# month =  02
# day =  21
# month =  02
# day =  22
# month =  02
# day =  23
# month =  02
# day =  24
# month =  02
# day =  25
# month =  02
# day =  26
# month =  02
# day =  27
# month =  02
# day =  28
# month =  02
# day =  01
# month =  03
# day =  02
# month =  03
# day =  03
# month =  03
# day =  04
# month =  03
# day =  05
# month =  03
# day =  06
# month =  03
# day =  07
# month =  03
# day =  08
# month =  03
# day =  09
# month =  03
# day =  10
# month =  03
# day =  11
# month =  03
# day =  12
# month =  03
# day =  13
# month =  03
# day =  14
# month =  03
# day =  15
# month =  03
# day =  16
# month =  03
# day =  17
# month =  03
# day =  18
# month =  03
# day =  19
# month =  03
# day =  20
# month =  03
# day =  21
# month =  03
# day =  22
# month =  03
# day =  23
# month =  03
# day =  24
# month =  03
# day =  25
# month =  03
# day =  26
# month =  03
# day =  27
# month =  03
# day =  28
# month =  03
# day =  01
# month =  04
# day =  02
# month =  04
# day =  03
# month =  04
# day =  04
# month =  04
# day =  05
# month =  04
# day =  06
# month =  04
# day =  07
# month =  04
# day =  08
# month =  04
# day =  09
# month =  04
# day =  10
# month =  04
# day =  11
# month =  04
# day =  12
# month =  04
# day =  13
# month =  04
# day =  14
# month =  04
# day =  15
# month =  04
# day =  16
# month =  04
# day =  17
# month =  04
# day =  18
# month =  04
# day =  19
# month =  04
# day =  20
# month =  04
# day =  21
# month =  04
# day =  22
# month =  04
# day =  23
# month =  04
# day =  24
# month =  04
# day =  25
# month =  04
# day =  26
# month =  04
# day =  27
# month =  04
# day =  28
# month =  04
# day =  01
# month =  05
# day =  02
# month =  05
# day =  03
# month =  05
# day =  04
# month =  05
# day =  05
# month =  05
# day =  06
# month =  05
# day =  07
# month =  05
# day =  08
# month =  05
# day =  09
# month =  05
# day =  10
# month =  05
# day =  11
# month =  05
# day =  12
# month =  05
# day =  13
# month =  05
# day =  14
# month =  05
# day =  15
# month =  05
# day =  16
# month =  05
# day =  17
# month =  05
# day =  18
# month =  05
# day =  19
# month =  05
# day =  20
# month =  05
# day =  21
# month =  05
# day =  22
# month =  05
# day =  23
# month =  05
# day =  24
# month =  05
# day =  25
# month =  05
# day =  26
# month =  05
# day =  27
# month =  05
# day =  28
# month =  05
# day =  01
# month =  06
# day =  02
# month =  06
# day =  03
# month =  06
# day =  04
# month =  06
# day =  05
# month =  06
# day =  06
# month =  06
# day =  07
# month =  06
# day =  08
# month =  06
# day =  09
# month =  06
# day =  10
# month =  06
# day =  11
# month =  06
# day =  12
# month =  06
# day =  13
# month =  06
# day =  14
# month =  06
# day =  15
# month =  06
# day =  16
# month =  06
# day =  17
# month =  06
# day =  18
# month =  06
# day =  19
# month =  06
# day =  20
# month =  06
# day =  21
# month =  06
# day =  22
# month =  06
# day =  23
# month =  06
# day =  24
# month =  06
# day =  25
# month =  06
# day =  26
# month =  06
# day =  27
# month =  06
# day =  28
# month =  06
# day =  01
# month =  07
# day =  02
# month =  07
# day =  03
# month =  07
# day =  04
# month =  07
# day =  05
# month =  07
# day =  06
# month =  07
# day =  07
# month =  07
# day =  08
# month =  07
# day =  09
# month =  07
# day =  10
# month =  07
# day =  11
# month =  07
# day =  12
# month =  07
# day =  13
# month =  07
# day =  14
# month =  07
# day =  15
# month =  07
# day =  16
# month =  07
# day =  17
# month =  07
# day =  18
# month =  07
# day =  19
# month =  07
# day =  20
# month =  07
# day =  21
# month =  07
# day =  22
# month =  07
# day =  23
# month =  07
# day =  24
# month =  07
# day =  25
# month =  07
# day =  26
# month =  07
# day =  27
# month =  07
# day =  28
# month =  07
# day =  01
# month =  08
# day =  02
# month =  08
# day =  03
# month =  08
# day =  04
# month =  08
# day =  05
# month =  08
# day =  06
# month =  08
# day =  07
# month =  08
# day =  08
# month =  08
# day =  09
# month =  08
# day =  10
# month =  08
# day =  11
# month =  08
# day =  12
# month =  08
# day =  13
# month =  08
# day =  14
# month =  08
# day =  15
# month =  08
# day =  16
# month =  08
# day =  17
# month =  08
# day =  18
# month =  08
# day =  19
# month =  08
# day =  20
# month =  08
# day =  21
# month =  08
# day =  22
# month =  08
# day =  23
# month =  08
# day =  24
# month =  08
# day =  25
# month =  08
# day =  26
# month =  08
# day =  27
# month =  08
# day =  28
# month =  08
# day =  01
# month =  09
# day =  02
# month =  09
# day =  03
# month =  09
# day =  04
# month =  09
# day =  05
# month =  09
# day =  06
# month =  09
# day =  07
# month =  09
# day =  08
# month =  09
# day =  09
# month =  09
# day =  10
# month =  09
# day =  11
# month =  09
# day =  12
# month =  09
# day =  13
# month =  09
# day =  14
# month =  09
# day =  15
# month =  09
# day =  16
# month =  09
# day =  17
# month =  09
# day =  18
# month =  09
# day =  19
# month =  09
# day =  20
# month =  09
# day =  21
# month =  09
# day =  22
# month =  09
# day =  23
# month =  09
# day =  24
# month =  09
# day =  25
# month =  09
# day =  26
# month =  09
# day =  27
# month =  09
# day =  28
# month =  09

# %%
parsed
# Out:
# {'currently': {'apparentTemperature': 42.13,
#   'cloudCover': 0.17,
#   'dewPoint': 26.29,
#   'humidity': 0.46,
#   'icon': 'clear-day',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'pressure': 1022.03,
#   'summary': 'Clear',
#   'temperature': 45.88,
#   'time': 1482944400,
#   'uvIndex': 2,
#   'visibility': 10,
#   'windBearing': 311,
#   'windSpeed': 7.19},
#  'daily': {'data': [{'apparentTemperatureMax': 50.11,
#     'apparentTemperatureMaxTime': 1482901200,
#     'apparentTemperatureMin': 34.13,
#     'apparentTemperatureMinTime': 1482984000,
#     'cloudCover': 0.06,
#     'dewPoint': 28.43,
#     'humidity': 0.55,
#     'icon': 'clear-day',
#     'moonPhase': 0.98,
#     'precipIntensity': 0,
#     'precipIntensityMax': 0,
#     'precipProbability': 0,
#     'pressure': 1019.93,
#     'summary': 'Clear throughout the day.',
#     'sunriseTime': 1482928030,
#     'sunsetTime': 1482962092,
#     'temperatureMax': 50.11,
#     'temperatureMaxTime': 1482901200,
#     'temperatureMin': 37.66,
#     'temperatureMinTime': 1482984000,
#     'time': 1482901200,
#     'uvIndex': 2,
#     'uvIndexTime': 1482944400,
#     'visibility': 10,
#     'windBearing': 318,
#     'windSpeed': 4.98}]},
#  'flags': {'isd-stations': ['720334-93764',
#    '722158-99999',
#    '722244-00358',
#    '724030-93738',
#    '724035-13773',
#    '724036-03710',
#    '724037-93728',
#    '724050-13743',
#    '724055-03714',
#    '724060-93721',
#    '724065-99999',
#    '745940-13705',
#    '994400-99999',
#    '997314-99999',
#    '998409-99999',
#    '999999-13752'],
#   'sources': ['isd'],
#   'units': 'us'},
#  'hourly': {'data': [{'apparentTemperature': 50.11,
#     'cloudCover': 0,
#     'dewPoint': 31.65,
#     'humidity': 0.49,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1015.54,
#     'summary': 'Clear',
#     'temperature': 50.11,
#     'time': 1482901200,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 315,
#     'windSpeed': 10.03},
#    {'apparentTemperature': 44.04,
#     'cloudCover': 0,
#     'dewPoint': 30.82,
#     'humidity': 0.5,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1015.89,
#     'summary': 'Clear',
#     'temperature': 48.78,
#     'time': 1482904800,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 320,
#     'windSpeed': 11.46},
#    {'apparentTemperature': 42.04,
#     'cloudCover': 0,
#     'dewPoint': 29.82,
#     'humidity': 0.51,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1016.44,
#     'summary': 'Clear',
#     'temperature': 47.19,
#     'time': 1482908400,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 318,
#     'windSpeed': 11.52},
#    {'apparentTemperature': 40.29,
#     'cloudCover': 0,
#     'dewPoint': 29.88,
#     'humidity': 0.54,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1017.25,
#     'summary': 'Clear',
#     'temperature': 45.74,
#     'time': 1482912000,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 328,
#     'windSpeed': 11.31},
#    {'apparentTemperature': 39.46,
#     'cloudCover': 0.02,
#     'dewPoint': 28.65,
#     'humidity': 0.53,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1017.97,
#     'summary': 'Clear',
#     'temperature': 44.51,
#     'time': 1482915600,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 322,
#     'windSpeed': 9.44},
#    {'apparentTemperature': 37.8,
#     'cloudCover': 0,
#     'dewPoint': 27.93,
#     'humidity': 0.55,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1018.88,
#     'summary': 'Clear',
#     'temperature': 43.07,
#     'time': 1482919200,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 309,
#     'windSpeed': 9.17},
#    {'apparentTemperature': 38.91,
#     'cloudCover': 0,
#     'dewPoint': 27.26,
#     'humidity': 0.56,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1019.84,
#     'summary': 'Clear',
#     'temperature': 42.01,
#     'time': 1482922800,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 320,
#     'windSpeed': 4.89},
#    {'apparentTemperature': 36.11,
#     'cloudCover': 0.01,
#     'dewPoint': 27.2,
#     'humidity': 0.6,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1020.76,
#     'summary': 'Clear',
#     'temperature': 39.94,
#     'time': 1482926400,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 334,
#     'windSpeed': 5.4},
#    {'apparentTemperature': 35.66,
#     'cloudCover': 0.12,
#     'dewPoint': 27.66,
#     'humidity': 0.61,
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1021.56,
#     'summary': 'Clear',
#     'temperature': 40.01,
#     'time': 1482930000,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 312,
#     'windSpeed': 6.16},
#    {'apparentTemperature': 37.21,
#     'cloudCover': 0.17,
#     'dewPoint': 26.53,
#     'humidity': 0.53,
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1022.38,
#     'summary': 'Clear',
#     'temperature': 42.33,
#     'time': 1482933600,
#     'uvIndex': 1,
#     'visibility': 10,
#     'windBearing': 310,
#     'windSpeed': 8.44},
#    {'apparentTemperature': 37.68,
#     'cloudCover': 0.15,
#     'dewPoint': 26.38,
#     'humidity': 0.5,
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1023.04,
#     'summary': 'Clear',
#     'temperature': 43.64,
#     'time': 1482937200,
#     'uvIndex': 1,
#     'visibility': 10,
#     'windBearing': 310,
#     'windSpeed': 11.28},
#    {'apparentTemperature': 40.92,
#     'cloudCover': 0.16,
#     'dewPoint': 26.49,
#     'humidity': 0.48,
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1022.79,
#     'summary': 'Clear',
#     'temperature': 44.99,
#     'time': 1482940800,
#     'uvIndex': 1,
#     'visibility': 10,
#     'windBearing': 321,
#     'windSpeed': 7.45},
#    {'apparentTemperature': 42.13,
#     'cloudCover': 0.17,
#     'dewPoint': 26.29,
#     'humidity': 0.46,
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1022.03,
#     'summary': 'Clear',
#     'temperature': 45.88,
#     'time': 1482944400,
#     'uvIndex': 2,
#     'visibility': 10,
#     'windBearing': 311,
#     'windSpeed': 7.19},
#    {'apparentTemperature': 43.12,
#     'cloudCover': 0.16,
#     'dewPoint': 26.25,
#     'humidity': 0.44,
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1021.16,
#     'summary': 'Clear',
#     'temperature': 46.92,
#     'time': 1482948000,
#     'uvIndex': 2,
#     'visibility': 10,
#     'windBearing': 312,
#     'windSpeed': 7.77},
#    {'apparentTemperature': 44.79,
#     'cloudCover': 0.14,
#     'dewPoint': 25.86,
#     'humidity': 0.42,
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1020.82,
#     'summary': 'Clear',
#     'temperature': 47.95,
#     'time': 1482951600,
#     'uvIndex': 1,
#     'visibility': 10,
#     'windBearing': 302,
#     'windSpeed': 6.84},
#    {'apparentTemperature': 46.42,
#     'cloudCover': 0.13,
#     'dewPoint': 25.47,
#     'humidity': 0.4,
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1020.54,
#     'summary': 'Clear',
#     'temperature': 48.77,
#     'time': 1482955200,
#     'uvIndex': 1,
#     'visibility': 10,
#     'windBearing': 290,
#     'windSpeed': 5.59},
#    {'apparentTemperature': 47.2,
#     'cloudCover': 0.12,
#     'dewPoint': 25.95,
#     'humidity': 0.41,
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1020.41,
#     'summary': 'Clear',
#     'temperature': 48.74,
#     'time': 1482958800,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 328,
#     'windSpeed': 4.3},
#    {'apparentTemperature': 43.65,
#     'cloudCover': 0.13,
#     'dewPoint': 29.43,
#     'humidity': 0.54,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1019.95,
#     'summary': 'Clear',
#     'temperature': 45.06,
#     'time': 1482962400,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 22,
#     'windSpeed': 3.44},
#    {'apparentTemperature': 42.9,
#     'cloudCover': 0.01,
#     'dewPoint': 30.78,
#     'humidity': 0.62,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1020.2,
#     'summary': 'Clear',
#     'temperature': 42.9,
#     'time': 1482966000,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 99,
#     'windSpeed': 1.81},
#    {'apparentTemperature': 41.22,
#     'cloudCover': 0.01,
#     'dewPoint': 29.83,
#     'humidity': 0.64,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1020.48,
#     'summary': 'Clear',
#     'temperature': 41.22,
#     'time': 1482969600,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 104,
#     'windSpeed': 2.59},
#    {'apparentTemperature': 39.59,
#     'cloudCover': 0.01,
#     'dewPoint': 30.42,
#     'humidity': 0.69,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1020.62,
#     'summary': 'Clear',
#     'temperature': 39.59,
#     'time': 1482973200,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 123,
#     'windSpeed': 2.61},
#    {'apparentTemperature': 35.84,
#     'cloudCover': 0,
#     'dewPoint': 30.47,
#     'humidity': 0.73,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1020.44,
#     'summary': 'Clear',
#     'temperature': 38.22,
#     'time': 1482976800,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 134,
#     'windSpeed': 3.44},
#    {'apparentTemperature': 34.3,
#     'cloudCover': 0,
#     'dewPoint': 30.43,
#     'humidity': 0.75,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1020.05,
#     'summary': 'Clear',
#     'temperature': 37.74,
#     'time': 1482980400,
#     'uvIndex': 0,
#     'visibility': 9.94,
#     'windBearing': 150,
#     'windSpeed': 4.43},
#    {'apparentTemperature': 34.13,
#     'cloudCover': 0,
#     'dewPoint': 30.91,
#     'humidity': 0.76,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1019.26,
#     'summary': 'Clear',
#     'temperature': 37.66,
#     'time': 1482984000,
#     'uvIndex': 0,
#     'visibility': 10,
#     'windBearing': 145,
#     'windSpeed': 4.52}],
#   'icon': 'clear-day',
#   'summary': 'Clear throughout the day.'},
#  'latitude': 38.889939,
#  'longitude': -77.009051,
#  'offset': -5,
#  'timezone': 'America/New_York'}

# %%
df = pd.read_csv('weather.csv')
df
# Out:
#      01  01.1   44.4       0  0.57
# 0     1     2  44.39  0.0000  0.43
# 1     1     3  47.80  0.0000  0.44
# 2     1     4  35.83  0.0000  0.40
# 3     1     5  27.33  0.0000  0.35
# 4     1     6  34.72  0.0000  0.32
# 5     1     7  39.56  0.0000  0.82
# 6     1     8  41.55  0.0000  0.95
# 7     1     9  46.13  0.0000  0.93
# 8     1    10  60.10  0.0000  0.68
# 9     1    11  36.01  0.0000  0.31
# 10    1    12  41.30  0.0000  0.38
# 11    1    13  27.05  0.0000  0.33
# 12    1    14  43.40  0.0000  0.40
# 13    1    15  47.73  0.0000  0.53
# 14    1    16  46.64  0.0000  0.82
# 15    1    17  33.63  0.0000  0.86
# 16    1    18  22.77  0.0000  0.39
# 17    1    19  22.59  0.0000  0.37
# 18    1    20  27.40  0.0000  0.43
# 19    1    21  30.50  0.0000  0.55
# 20    1    22  28.56  0.0000  0.54
# 21    1    23  27.37  0.0049  0.86
# 22    1    24  30.21  0.0000  0.44
# 23    1    25  35.72  0.0000  0.51
# 24    1    26  46.00  0.0021  0.51
# 25    1    27  41.15  0.0000  0.49
# 26    1    28  37.57  0.0000  0.55
# 27    2     1  56.71  0.0000  0.62
# 28    2     2  47.37  0.0000  0.54
# 29    2     3  48.73  0.0040  0.93
# ..   ..   ...    ...     ...   ...
# 305  11    27  49.27  0.0000  0.42
# 306  11    28  48.12  0.0000  0.55
# 307  12     1  55.10  0.0000  0.43
# 308  12     2  49.67  0.0000  0.42
# 309  12     3  48.26  0.0000  0.47
# 310  12     4  45.04  0.0000  0.53
# 311  12     5  51.62  0.0000  0.66
# 312  12     6  41.62  0.0345  0.85
# 313  12     7  47.95  0.0000  0.60
# 314  12     8  45.89  0.0000  0.39
# 315  12     9  37.40  0.0000  0.43
# 316  12    10  35.32  0.0000  0.39
# 317  12    11  35.69  0.0000  0.51
# 318  12    12  47.37  0.0000  0.91
# 319  12    13  43.28  0.0000  0.59
# 320  12    14  44.83  0.0000  0.45
# 321  12    15  24.76  0.0000  0.25
# 322  12    16  24.29  0.0000  0.31
# 323  12    17  33.02  0.0049  0.94
# 324  12    18  58.78  0.0012  0.85
# 325  12    19  34.66  0.0000  0.49
# 326  12    20  32.90  0.0000  0.48
# 327  12    21  44.88  0.0000  0.39
# 328  12    22  51.54  0.0000  0.38
# 329  12    23  44.03  0.0000  0.47
# 330  12    24  44.30  0.0064  0.95
# 331  12    25  46.62  0.0000  0.67
# 332  12    26  43.31  0.0000  0.78
# 333  12    27  60.51  0.0000  0.74
# 334  12    28  45.88  0.0000  0.46
#
# [335 rows x 5 columns]

# %%
df.columns = ["month", "day", "temp", "precip", "humidity"]

# %%
df
# Out:
#      month  day   temp  precip  humidity
# 0        1    2  44.39  0.0000      0.43
# 1        1    3  47.80  0.0000      0.44
# 2        1    4  35.83  0.0000      0.40
# 3        1    5  27.33  0.0000      0.35
# 4        1    6  34.72  0.0000      0.32
# 5        1    7  39.56  0.0000      0.82
# 6        1    8  41.55  0.0000      0.95
# 7        1    9  46.13  0.0000      0.93
# 8        1   10  60.10  0.0000      0.68
# 9        1   11  36.01  0.0000      0.31
# 10       1   12  41.30  0.0000      0.38
# 11       1   13  27.05  0.0000      0.33
# 12       1   14  43.40  0.0000      0.40
# 13       1   15  47.73  0.0000      0.53
# 14       1   16  46.64  0.0000      0.82
# 15       1   17  33.63  0.0000      0.86
# 16       1   18  22.77  0.0000      0.39
# 17       1   19  22.59  0.0000      0.37
# 18       1   20  27.40  0.0000      0.43
# 19       1   21  30.50  0.0000      0.55
# 20       1   22  28.56  0.0000      0.54
# 21       1   23  27.37  0.0049      0.86
# 22       1   24  30.21  0.0000      0.44
# 23       1   25  35.72  0.0000      0.51
# 24       1   26  46.00  0.0021      0.51
# 25       1   27  41.15  0.0000      0.49
# 26       1   28  37.57  0.0000      0.55
# 27       2    1  56.71  0.0000      0.62
# 28       2    2  47.37  0.0000      0.54
# 29       2    3  48.73  0.0040      0.93
# ..     ...  ...    ...     ...       ...
# 305     11   27  49.27  0.0000      0.42
# 306     11   28  48.12  0.0000      0.55
# 307     12    1  55.10  0.0000      0.43
# 308     12    2  49.67  0.0000      0.42
# 309     12    3  48.26  0.0000      0.47
# 310     12    4  45.04  0.0000      0.53
# 311     12    5  51.62  0.0000      0.66
# 312     12    6  41.62  0.0345      0.85
# 313     12    7  47.95  0.0000      0.60
# 314     12    8  45.89  0.0000      0.39
# 315     12    9  37.40  0.0000      0.43
# 316     12   10  35.32  0.0000      0.39
# 317     12   11  35.69  0.0000      0.51
# 318     12   12  47.37  0.0000      0.91
# 319     12   13  43.28  0.0000      0.59
# 320     12   14  44.83  0.0000      0.45
# 321     12   15  24.76  0.0000      0.25
# 322     12   16  24.29  0.0000      0.31
# 323     12   17  33.02  0.0049      0.94
# 324     12   18  58.78  0.0012      0.85
# 325     12   19  34.66  0.0000      0.49
# 326     12   20  32.90  0.0000      0.48
# 327     12   21  44.88  0.0000      0.39
# 328     12   22  51.54  0.0000      0.38
# 329     12   23  44.03  0.0000      0.47
# 330     12   24  44.30  0.0064      0.95
# 331     12   25  46.62  0.0000      0.67
# 332     12   26  43.31  0.0000      0.78
# 333     12   27  60.51  0.0000      0.74
# 334     12   28  45.88  0.0000      0.46
#
# [335 rows x 5 columns]
